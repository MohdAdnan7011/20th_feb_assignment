# %%
# Question Number 1
'''GET Method: Used to retrieve data. Data is appended to the URL,
    making it visible and less secure. GET requests can be cached and are idempotent.
    
POST Method: Used to submit data. Data is sent in the request body,
    making it more secure for sensitive information. POST requests are not cached and are not idempotent.'''
# Out:
# 'GET Method: Used to retrieve data. Data is appended to the URL,\n    making it visible and less secure. GET requests can be cached and are idempotent.\n    \nPOST Method: Used to submit data. Data is sent in the request body,\n    making it more secure for sensitive information. POST requests are not cached and are not idempotent.'

# %%
# Question Number 2
'''In Flask, the request object is used to access and interact with incoming HTTP requests.
It provides a way to retrieve data sent by the client to the server, such as form data,
query parameters, headers, cookies, and file uploads.
This allows you to handle and process the data in your Flask application.'''
# Out:
# 'In Flask, the request object is used to access and interact with incoming HTTP requests.\nIt provides a way to retrieve data sent by the client to the server, such as form data,\nquery parameters, headers, cookies, and file uploads.\nThis allows you to handle and process the data in your Flask application.'

# %%
# Question Number 3
'''In Flask, the redirect() function is used to send a client to a different URL.
This is useful in a variety of scenarios, such as after a form submission,
when a user needs to be taken to another page, or when you need to handle routes dynamically.'''

# %%
# Question Number 4
'''Templates in Flask are used to create HTML files that can dynamically generate content.
They allow you to separate the design (HTML/CSS) from the logic (Python code) of your web application,
making it easier to manage and maintain.

The render_template() function is used to render an HTML template with dynamic content.
It takes the name of the template file and any variables you want to pass to the template.'''
# Out:
# 'Templates in Flask are used to create HTML files that can dynamically generate content.\nThey allow you to separate the design (HTML/CSS) from the logic (Python code) of your web application,\nmaking it easier to manage and maintain.\n\nThe render_template() function is used to render an HTML template with dynamic content.\nIt takes the name of the template file and any variables you want to pass to the template.'

# %% [markdown]
# # Question Number 5
# ![adnan.jpg](attachment:adnan.jpg)
